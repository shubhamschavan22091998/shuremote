# %% [markdown]
# # AWS Glue Studio Notebook
# ##### You are now running a AWS Glue Studio notebook; To start using your notebook you need to start an AWS Glue Interactive Session.

# %% [markdown]
# #### Optional: Run this cell to see available notebook commands ("magics").

# %%
# %help

# %%
# %idle_timeout 2880
# %glue_version 5.0
# %worker_type G.1X
# %number_of_workers 5
# %%configure
{
  "--job-bookmark-option": "job-bookmark-enable",
  "--enable-spark-ui": "true",
}
# Out:
# Welcome to the Glue Interactive Sessions Kernel
# For more information on available magic commands, please type %help in any new cell.
#
# Please view our Getting Started page to access the most up-to-date information on the Interactive Sessions kernel: https://docs.aws.amazon.com/glue/latest/dg/interactive-sessions.html
# Installed kernel version: 1.0.7
# Current idle_timeout is None minutes.
# idle_timeout has been set to 2880 minutes.
# Setting Glue version to: 5.0
# Previous worker type: None
# Setting new worker type to: G.1X
# Previous number of workers: None
# Setting new number of workers to: 5
# The following configurations have been updated: {'--job-bookmark-option': 'job-bookmark-enable', '--enable-spark-ui': 'true'}

# %% [markdown]
# ####  Run this cell to set up and start your interactive session.

# %%
import sys
from awsglue.transforms import *
from awsglue.utils import getResolvedOptions
from pyspark.context import SparkContext
from awsglue.context import GlueContext
from awsglue.job import Job
  
sc = SparkContext.getOrCreate()
glueContext = GlueContext(sc)
spark = glueContext.spark_session
job = Job(glueContext)
# Out:
# Trying to create a Glue session for the kernel.
# Session Type: glueetl
# Worker Type: G.1X
# Number of Workers: 5
# Idle Timeout: 2880
# Session ID: 6ac63b03-1de2-4ddf-a23b-3d9371537e75
# Applying the following default arguments:
# --glue_kernel_version 1.0.7
# --enable-glue-datacatalog true
# --job-bookmark-option job-bookmark-enable
# --enable-spark-ui true
# Waiting for session 6ac63b03-1de2-4ddf-a23b-3d9371537e75 to get into ready status...
# Session 6ac63b03-1de2-4ddf-a23b-3d9371537e75 has been created.

# %% [markdown]
# #### Example: Create a DynamicFrame from a table in the AWS Glue Data Catalog and display its schema

# %%
dyf = glueContext.create_dynamic_frame.from_catalog(database='new_data', table_name='sales_transactions_csv',
                                                    transformation_ctx = "dyf1",
                                                    additional_options = {
                                                        "badRecordspath" : "s3://practice-spark-shu/bad-data/"
                                                    }
                                                   )
dyf.printSchema()
# Out:
# root
# |-- transaction_id: long
# |-- order_id: string
# |-- customer_id: string
# |-- customer_name: string
# |-- customer_email: string
# |-- customer_city: string
# |-- customer_state: string
# |-- product_id: string
# |-- product_name: string
# |-- product_category: string
# |-- quantity: long
# |-- unit_price: long
# |-- discount_pct: long
# |-- tax_pct: long
# |-- payment_mode: string
# |-- order_status: string
# |-- order_date: string
# |-- ingestion_timestamp: string
# |-- gross_amount: long
# |-- net_amount: long

# %%
df = dyf.toDF()
df.show()
# Out:
# +--------------+--------+-----------+-------------+--------------------+---------------+--------------+----------+------------+----------------+--------+----------+------------+-------+------------+------------+----------+-------------------+------------+----------+
# |transaction_id|order_id|customer_id|customer_name|      customer_email|  customer_city|customer_state|product_id|product_name|product_category|quantity|unit_price|discount_pct|tax_pct|payment_mode|order_status|order_date|ingestion_timestamp|gross_amount|net_amount|
# +--------------+--------+-----------+-------------+--------------------+---------------+--------------+----------+------------+----------------+--------+----------+------------+-------+------------+------------+----------+-------------------+------------+----------+
# |             1| ORD1001|       C005|    Patrick@@|vcunningham@sanch...|       Grayview|            MH|      P231|      result|         INVALID|       3|         0|           0|     18|        cash|   DELIVERED|02-01-2026|            35:43.9|        NULL|      NULL|
# |             2| ORD1002|       C018|       Hector|stephaniewatson@m...|     South Lisa|            KA|      P178|        call|       Furniture|      -1|       100|          10|     18|        cash|   DELIVERED|28-12-2025|            16:43.9|        NULL|      NULL|
# |             3| ORD1003|       C022|       Andrew| bschaefer@yahoo.com|      Lake Lisa|            MH|      P233|      manage|     Electronics|       2|         0|          10|     18|         UPI|   CANCELLED|02-01-2026|            44:43.9|        NULL|      NULL|
# |             4| ORD1004|       C032|     Brittany|bernardnovak@herr...|   Evansborough|            XX|      P201|      rather|         INVALID|       3|         0|          10|      5|         UPI|    RETURNED|28-12-2025|            28:43.9|        NULL|      NULL|
# |             5| ORD1005|       C029|       Monica|    yharris@huff.com|South Alexander|            KA|      P202|       staff|         INVALID|      -1|       100|           5|     12|        cash|    RETURNED|02-01-2026|            55:43.9|        NULL|      NULL|
# |             6| ORD1006|       C050|        Aaron| graynancy@yahoo.com|    Kathleenton|            MH|      P112|          in|         INVALID|       2|         0|          15|     12|        card|    RETURNED|02-01-2026|            21:43.9|        NULL|      NULL|
# |             7| ORD1007|       C046|     Joshua@@|hardyernest@gmail...|     South Mary|            MH|      P231|      camera|     Electronics|       2|       500|          15|      5|         UPI|    RETURNED|02-01-2026|            03:43.9|        1000|       850|
# |             8| ORD1008|       C029|       Steven|randymosley@hotma...|South Meganberg|            MH|      P140|       about|     Electronics|      -1|         0|           0|     18|        cash|    RETURNED|02-01-2026|            37:43.9|        NULL|      NULL|
# |             9| ORD1009|       C042|         Jill| wendy06@hotmail.com|     Lake Dylan|            KA|      P273|    continue|     Electronics|       3|       500|          15|     12|        card|   DELIVERED|28-12-2025|            07:43.9|        1500|      1275|
# |            10| ORD1010|       C027|       Daniel| debrahall@yahoo.com|  New Bryantown|            KA|      P184|       voice|       Furniture|      -1|         0|           0|     12|        card|   CANCELLED|28-12-2025|            12:43.9|        NULL|      NULL|
# |            11| ORD1011|       C010|      Terri@@|     xcook@gmail.com|      Ericmouth|            KA|      P202|         red|         INVALID|       2|       100|           5|      5|        cash|   DELIVERED|02-01-2026|            49:43.9|         200|       190|
# |            12| ORD1012|       C005|         John|    ogomez@yahoo.com|     Jonesmouth|            MH|      P195|         hot|         INVALID|      -1|       500|           5|      5|         UPI|   DELIVERED|02-01-2026|            30:43.9|        NULL|      NULL|
# |            13| ORD1013|       C027|       Justin|lindsey23@singh-n...|      Welchbury|            XX|      P114|     compare|         INVALID|       1|       500|           5|      5|        cash|   DELIVERED|28-12-2025|            05:43.9|         500|       475|
# |            14| ORD1014|       C010|         Levi|zdouglas@wiley-st...|    New Matthew|            KA|      P228|       claim|     Electronics|       2|       100|           5|      5|         UPI|    RETURNED|28-12-2025|            07:43.9|         200|       190|
# |          NULL| ORD1015|       C042|     Victoria|   kim36@hotmail.com|  South Cynthia|            MH|      P110|     reflect|       Furniture|       3|         0|           0|      5|        cash|   DELIVERED|02-01-2026|            25:43.9|        NULL|      NULL|
# |            16| ORD1016|       C043|        Kevin|grayhannah@hotmai...|  New Joelmouth|            KA|      P242|        wide|     Electronics|       1|         0|           0|     18|        cash|   DELIVERED|28-12-2025|            22:43.9|        NULL|      NULL|
# |            17| ORD1017|       C034|        Randy|nicholasgonzales@...|  Kimberlymouth|            KA|      P250|       glass|       Furniture|       3|       100|           0|     18|         UPI|    RETURNED|28-12-2025|            13:43.9|         300|       300|
# |            18| ORD1018|       C002|        Kevin|           bad_email|   South Andrea|            KA|      P125|        dark|     Electronics|       1|       100|          15|     12|        card|    RETURNED|28-12-2025|            22:43.9|         100|        85|
# |            19| ORD1019|       C022|        Jason|orodriguez@fields...|    Port Pamela|            XX|      P170|         not|     Electronics|      -1|         0|          10|     12|        card|   CANCELLED|28-12-2025|            17:43.9|        NULL|      NULL|
# |            20| ORD1005|       C021|     Patricia|jasondiaz@wallace...|        Hahnton|            MH|      P242|   financial|         INVALID|       3|       100|           5|     12|        card|   DELIVERED|28-12-2025|            27:43.9|         300|       285|
# +--------------+--------+-----------+-------------+--------------------+---------------+--------------+----------+------------+----------------+--------+----------+------------+-------+------------+------------+----------+-------------------+------------+----------+
# only showing top 20 rows
#
# /usr/lib/spark/python/lib/pyspark.zip/pyspark/sql/dataframe.py:147: UserWarning: DataFrame constructor is internal. Do not directly use it.

# %%
from pyspark.sql.functions import col,lit,when, avg, mean, mode,upper, rank, row_number, dense_rank,count, to_date, to_timestamp, current_date, lower, regexp_extract, length, percentile_approx,year,month,day
from pyspark.sql.window import Window

# %%
#Null check on primary keys
df1 = df
df1.filter(col("transaction_id").isNull()).show()
# Out:
# +--------------+--------+-----------+-------------+--------------------+------------------+--------------+----------+------------+----------------+--------+----------+------------+-------+------------+------------+----------+-------------------+------------+----------+
# |transaction_id|order_id|customer_id|customer_name|      customer_email|     customer_city|customer_state|product_id|product_name|product_category|quantity|unit_price|discount_pct|tax_pct|payment_mode|order_status|order_date|ingestion_timestamp|gross_amount|net_amount|
# +--------------+--------+-----------+-------------+--------------------+------------------+--------------+----------+------------+----------------+--------+----------+------------+-------+------------+------------+----------+-------------------+------------+----------+
# |          NULL| ORD1015|       C042|     Victoria|   kim36@hotmail.com|     South Cynthia|            MH|      P110|     reflect|       Furniture|       3|         0|           0|      5|        cash|   DELIVERED|02-01-2026|            25:43.9|        NULL|      NULL|
# |          NULL| ORD1030|       C004|       Monica| erinwise@savage.org|     New Katherine|            XX|      P254|         gun|         INVALID|       1|       100|          15|      5|        cash|   CANCELLED|28-12-2025|            48:43.9|         100|        85|
# |          NULL| ORD1045|       C011|        Carly|harrisangela@sull...|  Fitzpatrickville|            MH|      P139|     western|       Furniture|       3|       100|           5|     12|        card|   DELIVERED|28-12-2025|            18:43.9|         300|       285|
# |          NULL| ORD1005|       C028|      Crystal|forddennis@hotmai...|        Martinberg|            MH|      P133|        wind|       Furniture|       1|       100|          15|     12|        cash|   CANCELLED|28-12-2025|            28:43.9|         100|        85|
# |          NULL| ORD1075|       C025|      Krystal|riverasusan@hobbs...|         Sharpfort|            MH|      P284|       store|     Electronics|       2|       100|          10|     18|        card|    RETURNED|02-01-2026|            42:43.9|         200|       180|
# |          NULL| ORD1090|       C043|     Clifford|           bad_email|East Danielleburgh|            KA|      P278|        hear|       Furniture|      -1|         0|           5|     18|        cash|    RETURNED|28-12-2025|            31:43.9|        NULL|      NULL|
# |          NULL| ORD1105|       C037|        Penny|amiles@hall-gilmo...|          Sethside|            KA|      P195|        part|         INVALID|      -1|       100|           5|     18|         UPI|    RETURNED|28-12-2025|            06:43.9|        NULL|      NULL|
# |          NULL| ORD1005|       C029|     Jonathan| hshepherd@gmail.com|        Anitamouth|            MH|      P197|       enter|     Electronics|      -1|         0|          10|     18|        card|   DELIVERED|28-12-2025|            32:43.9|        NULL|      NULL|
# |          NULL| ORD1135|       C008|      Shelley|alicemiller@gmail...|    Port Karentown|            MH|      P112|         new|     Electronics|       2|       100|           5|     18|        card|   DELIVERED|02-01-2026|            09:43.9|         200|       190|
# |          NULL| ORD1150|       C045|        Megan|fwright@edwards.info|  North Pamelaland|            XX|      P244|        turn|       Furniture|       3|       100|          10|     12|        card|   CANCELLED|02-01-2026|            57:43.9|         300|       270|
# |          NULL| ORD1165|       C013|         Lynn|brownthomas@yahoo...|     Stephaniefurt|            MH|      P224|    pressure|       Furniture|       3|         0|          15|     12|         UPI|   CANCELLED|28-12-2025|            02:44.0|        NULL|      NULL|
# |          NULL| ORD1005|       C044|      Matthew|           bad_email|       Vegaborough|            KA|      P250|     prepare|       Furniture|       3|       500|          10|     12|         UPI|   CANCELLED|28-12-2025|            58:44.0|        1500|      1350|
# |          NULL| ORD1195|       C045|     Jennifer|    bhaley@yahoo.com|       Lindseyfort|            XX|      P114|       heavy|     Electronics|       2|       100|           0|     18|         UPI|    RETURNED|02-01-2026|            48:44.0|         200|       200|
# |          NULL| ORD1210|       C042|      Gregory| jameswall@yahoo.com|         Lake Anna|            XX|      P283|       great|       Furniture|       2|       500|           0|     18|         UPI|   DELIVERED|02-01-2026|            08:44.0|        1000|      1000|
# +--------------+--------+-----------+-------------+--------------------+------------------+--------------+----------+------------+----------------+--------+----------+------------+-------+------------+------------+----------+-------------------+------------+----------+

# %% [markdown]
# #### Example: Write the data in the DynamicFrame to a location in Amazon S3 and a table for it in the AWS Glue Data Catalog

# %%
#Reject negative quantity
df1 = df1.withColumn("rejection_flag",when(col("quantity") < 0, lit(True)).
                     when(col("unit_price") == 0, lit(True)).
                     otherwise(lit(False))
                    )

# %%
df1.show()
# Out:
# +--------------+--------+-----------+-------------+--------------------+---------------+--------------+----------+------------+----------------+--------+----------+------------+-------+------------+------------+----------+-------------------+------------+----------+--------------+
# |transaction_id|order_id|customer_id|customer_name|      customer_email|  customer_city|customer_state|product_id|product_name|product_category|quantity|unit_price|discount_pct|tax_pct|payment_mode|order_status|order_date|ingestion_timestamp|gross_amount|net_amount|rejection_flag|
# +--------------+--------+-----------+-------------+--------------------+---------------+--------------+----------+------------+----------------+--------+----------+------------+-------+------------+------------+----------+-------------------+------------+----------+--------------+
# |             1| ORD1001|       C005|    Patrick@@|vcunningham@sanch...|       Grayview|            MH|      P231|      result|         INVALID|       3|         0|           0|     18|        cash|   DELIVERED|02-01-2026|            35:43.9|        NULL|      NULL|          true|
# |             2| ORD1002|       C018|       Hector|stephaniewatson@m...|     South Lisa|            KA|      P178|        call|       Furniture|      -1|       100|          10|     18|        cash|   DELIVERED|28-12-2025|            16:43.9|        NULL|      NULL|          true|
# |             3| ORD1003|       C022|       Andrew| bschaefer@yahoo.com|      Lake Lisa|            MH|      P233|      manage|     Electronics|       2|         0|          10|     18|         UPI|   CANCELLED|02-01-2026|            44:43.9|        NULL|      NULL|          true|
# |             4| ORD1004|       C032|     Brittany|bernardnovak@herr...|   Evansborough|            XX|      P201|      rather|         INVALID|       3|         0|          10|      5|         UPI|    RETURNED|28-12-2025|            28:43.9|        NULL|      NULL|          true|
# |             5| ORD1005|       C029|       Monica|    yharris@huff.com|South Alexander|            KA|      P202|       staff|         INVALID|      -1|       100|           5|     12|        cash|    RETURNED|02-01-2026|            55:43.9|        NULL|      NULL|          true|
# |             6| ORD1006|       C050|        Aaron| graynancy@yahoo.com|    Kathleenton|            MH|      P112|          in|         INVALID|       2|         0|          15|     12|        card|    RETURNED|02-01-2026|            21:43.9|        NULL|      NULL|          true|
# |             7| ORD1007|       C046|     Joshua@@|hardyernest@gmail...|     South Mary|            MH|      P231|      camera|     Electronics|       2|       500|          15|      5|         UPI|    RETURNED|02-01-2026|            03:43.9|        1000|       850|         false|
# |             8| ORD1008|       C029|       Steven|randymosley@hotma...|South Meganberg|            MH|      P140|       about|     Electronics|      -1|         0|           0|     18|        cash|    RETURNED|02-01-2026|            37:43.9|        NULL|      NULL|          true|
# |             9| ORD1009|       C042|         Jill| wendy06@hotmail.com|     Lake Dylan|            KA|      P273|    continue|     Electronics|       3|       500|          15|     12|        card|   DELIVERED|28-12-2025|            07:43.9|        1500|      1275|         false|
# |            10| ORD1010|       C027|       Daniel| debrahall@yahoo.com|  New Bryantown|            KA|      P184|       voice|       Furniture|      -1|         0|           0|     12|        card|   CANCELLED|28-12-2025|            12:43.9|        NULL|      NULL|          true|
# |            11| ORD1011|       C010|      Terri@@|     xcook@gmail.com|      Ericmouth|            KA|      P202|         red|         INVALID|       2|       100|           5|      5|        cash|   DELIVERED|02-01-2026|            49:43.9|         200|       190|         false|
# |            12| ORD1012|       C005|         John|    ogomez@yahoo.com|     Jonesmouth|            MH|      P195|         hot|         INVALID|      -1|       500|           5|      5|         UPI|   DELIVERED|02-01-2026|            30:43.9|        NULL|      NULL|          true|
# |            13| ORD1013|       C027|       Justin|lindsey23@singh-n...|      Welchbury|            XX|      P114|     compare|         INVALID|       1|       500|           5|      5|        cash|   DELIVERED|28-12-2025|            05:43.9|         500|       475|         false|
# |            14| ORD1014|       C010|         Levi|zdouglas@wiley-st...|    New Matthew|            KA|      P228|       claim|     Electronics|       2|       100|           5|      5|         UPI|    RETURNED|28-12-2025|            07:43.9|         200|       190|         false|
# |          NULL| ORD1015|       C042|     Victoria|   kim36@hotmail.com|  South Cynthia|            MH|      P110|     reflect|       Furniture|       3|         0|           0|      5|        cash|   DELIVERED|02-01-2026|            25:43.9|        NULL|      NULL|          true|
# |            16| ORD1016|       C043|        Kevin|grayhannah@hotmai...|  New Joelmouth|            KA|      P242|        wide|     Electronics|       1|         0|           0|     18|        cash|   DELIVERED|28-12-2025|            22:43.9|        NULL|      NULL|          true|
# |            17| ORD1017|       C034|        Randy|nicholasgonzales@...|  Kimberlymouth|            KA|      P250|       glass|       Furniture|       3|       100|           0|     18|         UPI|    RETURNED|28-12-2025|            13:43.9|         300|       300|         false|
# |            18| ORD1018|       C002|        Kevin|           bad_email|   South Andrea|            KA|      P125|        dark|     Electronics|       1|       100|          15|     12|        card|    RETURNED|28-12-2025|            22:43.9|         100|        85|         false|
# |            19| ORD1019|       C022|        Jason|orodriguez@fields...|    Port Pamela|            XX|      P170|         not|     Electronics|      -1|         0|          10|     12|        card|   CANCELLED|28-12-2025|            17:43.9|        NULL|      NULL|          true|
# |            20| ORD1005|       C021|     Patricia|jasondiaz@wallace...|        Hahnton|            MH|      P242|   financial|         INVALID|       3|       100|           5|     12|        card|   DELIVERED|28-12-2025|            27:43.9|         300|       285|         false|
# +--------------+--------+-----------+-------------+--------------------+---------------+--------------+----------+------------+----------------+--------+----------+------------+-------+------------+------------+----------+-------------------+------------+----------+--------------+
# only showing top 20 rows

# %%
w = Window.partitionBy("order_id").orderBy(col("order_id").asc())
df1.withColumn("rows",row_number().over(w)).filter(col("rows")>1).count()
# Out:
# 11

# %%
df1.select("*").groupBy("order_id").agg(count("*").alias("counts")).filter(col("counts") > 1).show()
# Out:
# +--------+------+
# |order_id|counts|
# +--------+------+
# | ORD1005|    12|
# +--------+------+

# %%
df1.filter(col("customer_city").isNull()).count()
# Out:
# 0

# %%
df1 = df1.withColumn("order_date",to_date(col("order_date"),"dd-MM-yyyy"))

# %%
df1.show()
# Out:
# +--------------+--------+-----------+-------------+--------------------+---------------+--------------+----------+------------+----------------+--------+----------+------------+-------+------------+------------+----------+-------------------+------------+----------+--------------+
# |transaction_id|order_id|customer_id|customer_name|      customer_email|  customer_city|customer_state|product_id|product_name|product_category|quantity|unit_price|discount_pct|tax_pct|payment_mode|order_status|order_date|ingestion_timestamp|gross_amount|net_amount|rejection_flag|
# +--------------+--------+-----------+-------------+--------------------+---------------+--------------+----------+------------+----------------+--------+----------+------------+-------+------------+------------+----------+-------------------+------------+----------+--------------+
# |             1| ORD1001|       C005|    Patrick@@|vcunningham@sanch...|       Grayview|            MH|      P231|      result|         INVALID|       3|         0|           0|     18|        cash|   DELIVERED|2026-01-02|            35:43.9|        NULL|      NULL|          true|
# |             2| ORD1002|       C018|       Hector|stephaniewatson@m...|     South Lisa|            KA|      P178|        call|       Furniture|      -1|       100|          10|     18|        cash|   DELIVERED|2025-12-28|            16:43.9|        NULL|      NULL|          true|
# |             3| ORD1003|       C022|       Andrew| bschaefer@yahoo.com|      Lake Lisa|            MH|      P233|      manage|     Electronics|       2|         0|          10|     18|         UPI|   CANCELLED|2026-01-02|            44:43.9|        NULL|      NULL|          true|
# |             4| ORD1004|       C032|     Brittany|bernardnovak@herr...|   Evansborough|            XX|      P201|      rather|         INVALID|       3|         0|          10|      5|         UPI|    RETURNED|2025-12-28|            28:43.9|        NULL|      NULL|          true|
# |             5| ORD1005|       C029|       Monica|    yharris@huff.com|South Alexander|            KA|      P202|       staff|         INVALID|      -1|       100|           5|     12|        cash|    RETURNED|2026-01-02|            55:43.9|        NULL|      NULL|          true|
# |             6| ORD1006|       C050|        Aaron| graynancy@yahoo.com|    Kathleenton|            MH|      P112|          in|         INVALID|       2|         0|          15|     12|        card|    RETURNED|2026-01-02|            21:43.9|        NULL|      NULL|          true|
# |             7| ORD1007|       C046|     Joshua@@|hardyernest@gmail...|     South Mary|            MH|      P231|      camera|     Electronics|       2|       500|          15|      5|         UPI|    RETURNED|2026-01-02|            03:43.9|        1000|       850|         false|
# |             8| ORD1008|       C029|       Steven|randymosley@hotma...|South Meganberg|            MH|      P140|       about|     Electronics|      -1|         0|           0|     18|        cash|    RETURNED|2026-01-02|            37:43.9|        NULL|      NULL|          true|
# |             9| ORD1009|       C042|         Jill| wendy06@hotmail.com|     Lake Dylan|            KA|      P273|    continue|     Electronics|       3|       500|          15|     12|        card|   DELIVERED|2025-12-28|            07:43.9|        1500|      1275|         false|
# |            10| ORD1010|       C027|       Daniel| debrahall@yahoo.com|  New Bryantown|            KA|      P184|       voice|       Furniture|      -1|         0|           0|     12|        card|   CANCELLED|2025-12-28|            12:43.9|        NULL|      NULL|          true|
# |            11| ORD1011|       C010|      Terri@@|     xcook@gmail.com|      Ericmouth|            KA|      P202|         red|         INVALID|       2|       100|           5|      5|        cash|   DELIVERED|2026-01-02|            49:43.9|         200|       190|         false|
# |            12| ORD1012|       C005|         John|    ogomez@yahoo.com|     Jonesmouth|            MH|      P195|         hot|         INVALID|      -1|       500|           5|      5|         UPI|   DELIVERED|2026-01-02|            30:43.9|        NULL|      NULL|          true|
# |            13| ORD1013|       C027|       Justin|lindsey23@singh-n...|      Welchbury|            XX|      P114|     compare|         INVALID|       1|       500|           5|      5|        cash|   DELIVERED|2025-12-28|            05:43.9|         500|       475|         false|
# |            14| ORD1014|       C010|         Levi|zdouglas@wiley-st...|    New Matthew|            KA|      P228|       claim|     Electronics|       2|       100|           5|      5|         UPI|    RETURNED|2025-12-28|            07:43.9|         200|       190|         false|
# |          NULL| ORD1015|       C042|     Victoria|   kim36@hotmail.com|  South Cynthia|            MH|      P110|     reflect|       Furniture|       3|         0|           0|      5|        cash|   DELIVERED|2026-01-02|            25:43.9|        NULL|      NULL|          true|
# |            16| ORD1016|       C043|        Kevin|grayhannah@hotmai...|  New Joelmouth|            KA|      P242|        wide|     Electronics|       1|         0|           0|     18|        cash|   DELIVERED|2025-12-28|            22:43.9|        NULL|      NULL|          true|
# |            17| ORD1017|       C034|        Randy|nicholasgonzales@...|  Kimberlymouth|            KA|      P250|       glass|       Furniture|       3|       100|           0|     18|         UPI|    RETURNED|2025-12-28|            13:43.9|         300|       300|         false|
# |            18| ORD1018|       C002|        Kevin|           bad_email|   South Andrea|            KA|      P125|        dark|     Electronics|       1|       100|          15|     12|        card|    RETURNED|2025-12-28|            22:43.9|         100|        85|         false|
# |            19| ORD1019|       C022|        Jason|orodriguez@fields...|    Port Pamela|            XX|      P170|         not|     Electronics|      -1|         0|          10|     12|        card|   CANCELLED|2025-12-28|            17:43.9|        NULL|      NULL|          true|
# |            20| ORD1005|       C021|     Patricia|jasondiaz@wallace...|        Hahnton|            MH|      P242|   financial|         INVALID|       3|       100|           5|     12|        card|   DELIVERED|2025-12-28|            27:43.9|         300|       285|         false|
# +--------------+--------+-----------+-------------+--------------------+---------------+--------------+----------+------------+----------------+--------+----------+------------+-------+------------+------------+----------+-------------------+------------+----------+--------------+
# only showing top 20 rows

# %%
df1.filter(col("order_date") > current_date()).show()
# Out:
# +--------------+--------+-----------+-------------+--------------------+----------------+--------------+----------+------------+----------------+--------+----------+------------+-------+------------+------------+----------+-------------------+------------+----------+--------------+
# |transaction_id|order_id|customer_id|customer_name|      customer_email|   customer_city|customer_state|product_id|product_name|product_category|quantity|unit_price|discount_pct|tax_pct|payment_mode|order_status|order_date|ingestion_timestamp|gross_amount|net_amount|rejection_flag|
# +--------------+--------+-----------+-------------+--------------------+----------------+--------------+----------+------------+----------------+--------+----------+------------+-------+------------+------------+----------+-------------------+------------+----------+--------------+
# |             1| ORD1001|       C005|    Patrick@@|vcunningham@sanch...|        Grayview|            MH|      P231|      result|         INVALID|       3|         0|           0|     18|        cash|   DELIVERED|2026-01-02|            35:43.9|        NULL|      NULL|          true|
# |             3| ORD1003|       C022|       Andrew| bschaefer@yahoo.com|       Lake Lisa|            MH|      P233|      manage|     Electronics|       2|         0|          10|     18|         UPI|   CANCELLED|2026-01-02|            44:43.9|        NULL|      NULL|          true|
# |             5| ORD1005|       C029|       Monica|    yharris@huff.com| South Alexander|            KA|      P202|       staff|         INVALID|      -1|       100|           5|     12|        cash|    RETURNED|2026-01-02|            55:43.9|        NULL|      NULL|          true|
# |             6| ORD1006|       C050|        Aaron| graynancy@yahoo.com|     Kathleenton|            MH|      P112|          in|         INVALID|       2|         0|          15|     12|        card|    RETURNED|2026-01-02|            21:43.9|        NULL|      NULL|          true|
# |             7| ORD1007|       C046|     Joshua@@|hardyernest@gmail...|      South Mary|            MH|      P231|      camera|     Electronics|       2|       500|          15|      5|         UPI|    RETURNED|2026-01-02|            03:43.9|        1000|       850|         false|
# |             8| ORD1008|       C029|       Steven|randymosley@hotma...| South Meganberg|            MH|      P140|       about|     Electronics|      -1|         0|           0|     18|        cash|    RETURNED|2026-01-02|            37:43.9|        NULL|      NULL|          true|
# |            11| ORD1011|       C010|      Terri@@|     xcook@gmail.com|       Ericmouth|            KA|      P202|         red|         INVALID|       2|       100|           5|      5|        cash|   DELIVERED|2026-01-02|            49:43.9|         200|       190|         false|
# |            12| ORD1012|       C005|         John|    ogomez@yahoo.com|      Jonesmouth|            MH|      P195|         hot|         INVALID|      -1|       500|           5|      5|         UPI|   DELIVERED|2026-01-02|            30:43.9|        NULL|      NULL|          true|
# |          NULL| ORD1015|       C042|     Victoria|   kim36@hotmail.com|   South Cynthia|            MH|      P110|     reflect|       Furniture|       3|         0|           0|      5|        cash|   DELIVERED|2026-01-02|            25:43.9|        NULL|      NULL|          true|
# |            21| ORD1021|       C010|        Laura|   amber31@ramos.com|        Ryanland|            KA|      P222|     herself|         INVALID|       2|       100|          10|     18|        card|   CANCELLED|2026-01-02|            14:43.9|         200|       180|         false|
# |            24| ORD1024|       C009|     Michelle|nburke@elliott-ro...|   Christinastad|            KA|      P110|        seat|     Electronics|       1|       500|           5|     12|        card|   CANCELLED|2026-01-02|            59:43.9|         500|       475|         false|
# |            27| ORD1027|       C043|       Ashlee|christopher37@mor...|      Masonshire|            XX|      P261|        soon|         INVALID|      -1|       100|          10|      5|        cash|   DELIVERED|2026-01-02|            35:43.9|        NULL|      NULL|          true|
# |            28| ORD1028|       C025|       Jody@@|vincentrodriguez@...|Port Ashleyburgh|            XX|      P246|     present|     Electronics|       2|       100|           0|     18|         UPI|    RETURNED|2026-01-02|            35:43.9|         200|       200|         false|
# |            29| ORD1029|       C042|       Tamara|ysullivan@mendez.com|        Woodland|            MH|      P218|         age|     Electronics|       2|         0|           5|     12|        card|    RETURNED|2026-01-02|            23:43.9|        NULL|      NULL|          true|
# |            33| ORD1033|       C001|        Jason|devinfreeman@gmai...|      South Eric|            XX|      P104|   condition|     Electronics|      -1|       500|          15|     12|        card|    RETURNED|2026-01-02|            26:43.9|        NULL|      NULL|          true|
# |            35| ORD1035|       C001|       Calvin|gzamora@carlson-s...|       Craigstad|            MH|      P208|         bad|         INVALID|       1|       500|          10|     12|        cash|   DELIVERED|2026-01-02|            16:43.9|         500|       450|         false|
# |            36| ORD1036|       C033|      Timothy|           bad_email|  East Annashire|            MH|      P126|    anything|     Electronics|       3|         0|           0|      5|        cash|   DELIVERED|2026-01-02|            47:43.9|        NULL|      NULL|          true|
# |            38| ORD1038|       C023|     Michelle|    kurt78@yahoo.com|    South Robert|            KA|      P150|        nice|       Furniture|      -1|         0|          10|     18|         UPI|   CANCELLED|2026-01-02|            06:43.9|        NULL|      NULL|          true|
# |            41| ORD1041|       C004|       Alan@@|tracyjohnson@henr...| North Ashleyton|            XX|      P200|        able|     Electronics|       2|       500|          10|     12|         UPI|    RETURNED|2026-01-02|            46:43.9|        1000|       900|         false|
# |            43| ORD1043|       C029|  Christopher| michael93@yahoo.com|      Taylorland|            XX|      P163|        also|       Furniture|      -1|       500|           0|     12|        cash|   CANCELLED|2026-01-02|            28:43.9|        NULL|      NULL|          true|
# +--------------+--------+-----------+-------------+--------------------+----------------+--------------+----------+------------+----------------+--------+----------+------------+-------+------------+------------+----------+-------------------+------------+----------+--------------+
# only showing top 20 rows

# %%
df1 = df1.withColumn("rejection_flag",when(col("order_date") > current_date(),lit(True)).otherwise(col("rejection_flag")))

# %%
df1.show()
# Out:
# +--------------+--------+-----------+-------------+--------------------+---------------+--------------+----------+------------+----------------+--------+----------+------------+-------+------------+------------+----------+-------------------+------------+----------+--------------+
# |transaction_id|order_id|customer_id|customer_name|      customer_email|  customer_city|customer_state|product_id|product_name|product_category|quantity|unit_price|discount_pct|tax_pct|payment_mode|order_status|order_date|ingestion_timestamp|gross_amount|net_amount|rejection_flag|
# +--------------+--------+-----------+-------------+--------------------+---------------+--------------+----------+------------+----------------+--------+----------+------------+-------+------------+------------+----------+-------------------+------------+----------+--------------+
# |             1| ORD1001|       C005|    Patrick@@|vcunningham@sanch...|       Grayview|            MH|      P231|      result|         INVALID|       3|         0|           0|     18|        cash|   DELIVERED|2026-01-02|            35:43.9|        NULL|      NULL|          true|
# |             2| ORD1002|       C018|       Hector|stephaniewatson@m...|     South Lisa|            KA|      P178|        call|       Furniture|      -1|       100|          10|     18|        cash|   DELIVERED|2025-12-28|            16:43.9|        NULL|      NULL|          true|
# |             3| ORD1003|       C022|       Andrew| bschaefer@yahoo.com|      Lake Lisa|            MH|      P233|      manage|     Electronics|       2|         0|          10|     18|         UPI|   CANCELLED|2026-01-02|            44:43.9|        NULL|      NULL|          true|
# |             4| ORD1004|       C032|     Brittany|bernardnovak@herr...|   Evansborough|            XX|      P201|      rather|         INVALID|       3|         0|          10|      5|         UPI|    RETURNED|2025-12-28|            28:43.9|        NULL|      NULL|          true|
# |             5| ORD1005|       C029|       Monica|    yharris@huff.com|South Alexander|            KA|      P202|       staff|         INVALID|      -1|       100|           5|     12|        cash|    RETURNED|2026-01-02|            55:43.9|        NULL|      NULL|          true|
# |             6| ORD1006|       C050|        Aaron| graynancy@yahoo.com|    Kathleenton|            MH|      P112|          in|         INVALID|       2|         0|          15|     12|        card|    RETURNED|2026-01-02|            21:43.9|        NULL|      NULL|          true|
# |             7| ORD1007|       C046|     Joshua@@|hardyernest@gmail...|     South Mary|            MH|      P231|      camera|     Electronics|       2|       500|          15|      5|         UPI|    RETURNED|2026-01-02|            03:43.9|        1000|       850|          true|
# |             8| ORD1008|       C029|       Steven|randymosley@hotma...|South Meganberg|            MH|      P140|       about|     Electronics|      -1|         0|           0|     18|        cash|    RETURNED|2026-01-02|            37:43.9|        NULL|      NULL|          true|
# |             9| ORD1009|       C042|         Jill| wendy06@hotmail.com|     Lake Dylan|            KA|      P273|    continue|     Electronics|       3|       500|          15|     12|        card|   DELIVERED|2025-12-28|            07:43.9|        1500|      1275|         false|
# |            10| ORD1010|       C027|       Daniel| debrahall@yahoo.com|  New Bryantown|            KA|      P184|       voice|       Furniture|      -1|         0|           0|     12|        card|   CANCELLED|2025-12-28|            12:43.9|        NULL|      NULL|          true|
# |            11| ORD1011|       C010|      Terri@@|     xcook@gmail.com|      Ericmouth|            KA|      P202|         red|         INVALID|       2|       100|           5|      5|        cash|   DELIVERED|2026-01-02|            49:43.9|         200|       190|          true|
# |            12| ORD1012|       C005|         John|    ogomez@yahoo.com|     Jonesmouth|            MH|      P195|         hot|         INVALID|      -1|       500|           5|      5|         UPI|   DELIVERED|2026-01-02|            30:43.9|        NULL|      NULL|          true|
# |            13| ORD1013|       C027|       Justin|lindsey23@singh-n...|      Welchbury|            XX|      P114|     compare|         INVALID|       1|       500|           5|      5|        cash|   DELIVERED|2025-12-28|            05:43.9|         500|       475|         false|
# |            14| ORD1014|       C010|         Levi|zdouglas@wiley-st...|    New Matthew|            KA|      P228|       claim|     Electronics|       2|       100|           5|      5|         UPI|    RETURNED|2025-12-28|            07:43.9|         200|       190|         false|
# |          NULL| ORD1015|       C042|     Victoria|   kim36@hotmail.com|  South Cynthia|            MH|      P110|     reflect|       Furniture|       3|         0|           0|      5|        cash|   DELIVERED|2026-01-02|            25:43.9|        NULL|      NULL|          true|
# |            16| ORD1016|       C043|        Kevin|grayhannah@hotmai...|  New Joelmouth|            KA|      P242|        wide|     Electronics|       1|         0|           0|     18|        cash|   DELIVERED|2025-12-28|            22:43.9|        NULL|      NULL|          true|
# |            17| ORD1017|       C034|        Randy|nicholasgonzales@...|  Kimberlymouth|            KA|      P250|       glass|       Furniture|       3|       100|           0|     18|         UPI|    RETURNED|2025-12-28|            13:43.9|         300|       300|         false|
# |            18| ORD1018|       C002|        Kevin|           bad_email|   South Andrea|            KA|      P125|        dark|     Electronics|       1|       100|          15|     12|        card|    RETURNED|2025-12-28|            22:43.9|         100|        85|         false|
# |            19| ORD1019|       C022|        Jason|orodriguez@fields...|    Port Pamela|            XX|      P170|         not|     Electronics|      -1|         0|          10|     12|        card|   CANCELLED|2025-12-28|            17:43.9|        NULL|      NULL|          true|
# |            20| ORD1005|       C021|     Patricia|jasondiaz@wallace...|        Hahnton|            MH|      P242|   financial|         INVALID|       3|       100|           5|     12|        card|   DELIVERED|2025-12-28|            27:43.9|         300|       285|         false|
# +--------------+--------+-----------+-------------+--------------------+---------------+--------------+----------+------------+----------------+--------+----------+------------+-------+------------+------------+----------+-------------------+------------+----------+--------------+
# only showing top 20 rows

# %%
df1 = df1.withColumn("customer_email", lower(col("customer_email")))

# %%
df1 = df1.withColumn("payment_mode", upper(col("payment_mode")))

# %%
# Out:
# +--------------+--------+-----------+-------------+--------------------+---------------+--------------+----------+------------+----------------+--------+----------+------------+-------+------------+------------+----------+-------------------+------------+----------+--------------+
# |transaction_id|order_id|customer_id|customer_name|      customer_email|  customer_city|customer_state|product_id|product_name|product_category|quantity|unit_price|discount_pct|tax_pct|payment_mode|order_status|order_date|ingestion_timestamp|gross_amount|net_amount|rejection_flag|
# +--------------+--------+-----------+-------------+--------------------+---------------+--------------+----------+------------+----------------+--------+----------+------------+-------+------------+------------+----------+-------------------+------------+----------+--------------+
# |             1| ORD1001|       C005|    Patrick@@|vcunningham@sanch...|       Grayview|            MH|      P231|      result|         INVALID|       3|         0|           0|     18|        CASH|   DELIVERED|2026-01-02|            35:43.9|        NULL|      NULL|          true|
# |             2| ORD1002|       C018|       Hector|stephaniewatson@m...|     South Lisa|            KA|      P178|        call|       Furniture|      -1|       100|          10|     18|        CASH|   DELIVERED|2025-12-28|            16:43.9|        NULL|      NULL|          true|
# |             3| ORD1003|       C022|       Andrew| bschaefer@yahoo.com|      Lake Lisa|            MH|      P233|      manage|     Electronics|       2|         0|          10|     18|         UPI|   CANCELLED|2026-01-02|            44:43.9|        NULL|      NULL|          true|
# |             4| ORD1004|       C032|     Brittany|bernardnovak@herr...|   Evansborough|            XX|      P201|      rather|         INVALID|       3|         0|          10|      5|         UPI|    RETURNED|2025-12-28|            28:43.9|        NULL|      NULL|          true|
# |             5| ORD1005|       C029|       Monica|    yharris@huff.com|South Alexander|            KA|      P202|       staff|         INVALID|      -1|       100|           5|     12|        CASH|    RETURNED|2026-01-02|            55:43.9|        NULL|      NULL|          true|
# |             6| ORD1006|       C050|        Aaron| graynancy@yahoo.com|    Kathleenton|            MH|      P112|          in|         INVALID|       2|         0|          15|     12|        CARD|    RETURNED|2026-01-02|            21:43.9|        NULL|      NULL|          true|
# |             7| ORD1007|       C046|     Joshua@@|hardyernest@gmail...|     South Mary|            MH|      P231|      camera|     Electronics|       2|       500|          15|      5|         UPI|    RETURNED|2026-01-02|            03:43.9|        1000|       850|          true|
# |             8| ORD1008|       C029|       Steven|randymosley@hotma...|South Meganberg|            MH|      P140|       about|     Electronics|      -1|         0|           0|     18|        CASH|    RETURNED|2026-01-02|            37:43.9|        NULL|      NULL|          true|
# |             9| ORD1009|       C042|         Jill| wendy06@hotmail.com|     Lake Dylan|            KA|      P273|    continue|     Electronics|       3|       500|          15|     12|        CARD|   DELIVERED|2025-12-28|            07:43.9|        1500|      1275|         false|
# |            10| ORD1010|       C027|       Daniel| debrahall@yahoo.com|  New Bryantown|            KA|      P184|       voice|       Furniture|      -1|         0|           0|     12|        CARD|   CANCELLED|2025-12-28|            12:43.9|        NULL|      NULL|          true|
# |            11| ORD1011|       C010|      Terri@@|     xcook@gmail.com|      Ericmouth|            KA|      P202|         red|         INVALID|       2|       100|           5|      5|        CASH|   DELIVERED|2026-01-02|            49:43.9|         200|       190|          true|
# |            12| ORD1012|       C005|         John|    ogomez@yahoo.com|     Jonesmouth|            MH|      P195|         hot|         INVALID|      -1|       500|           5|      5|         UPI|   DELIVERED|2026-01-02|            30:43.9|        NULL|      NULL|          true|
# |            13| ORD1013|       C027|       Justin|lindsey23@singh-n...|      Welchbury|            XX|      P114|     compare|         INVALID|       1|       500|           5|      5|        CASH|   DELIVERED|2025-12-28|            05:43.9|         500|       475|         false|
# |            14| ORD1014|       C010|         Levi|zdouglas@wiley-st...|    New Matthew|            KA|      P228|       claim|     Electronics|       2|       100|           5|      5|         UPI|    RETURNED|2025-12-28|            07:43.9|         200|       190|         false|
# |          NULL| ORD1015|       C042|     Victoria|   kim36@hotmail.com|  South Cynthia|            MH|      P110|     reflect|       Furniture|       3|         0|           0|      5|        CASH|   DELIVERED|2026-01-02|            25:43.9|        NULL|      NULL|          true|
# |            16| ORD1016|       C043|        Kevin|grayhannah@hotmai...|  New Joelmouth|            KA|      P242|        wide|     Electronics|       1|         0|           0|     18|        CASH|   DELIVERED|2025-12-28|            22:43.9|        NULL|      NULL|          true|
# |            17| ORD1017|       C034|        Randy|nicholasgonzales@...|  Kimberlymouth|            KA|      P250|       glass|       Furniture|       3|       100|           0|     18|         UPI|    RETURNED|2025-12-28|            13:43.9|         300|       300|         false|
# |            18| ORD1018|       C002|        Kevin|           bad_email|   South Andrea|            KA|      P125|        dark|     Electronics|       1|       100|          15|     12|        CARD|    RETURNED|2025-12-28|            22:43.9|         100|        85|         false|
# |            19| ORD1019|       C022|        Jason|orodriguez@fields...|    Port Pamela|            XX|      P170|         not|     Electronics|      -1|         0|          10|     12|        CARD|   CANCELLED|2025-12-28|            17:43.9|        NULL|      NULL|          true|
# |            20| ORD1005|       C021|     Patricia|jasondiaz@wallace...|        Hahnton|            MH|      P242|   financial|         INVALID|       3|       100|           5|     12|        CARD|   DELIVERED|2025-12-28|            27:43.9|         300|       285|         false|
# +--------------+--------+-----------+-------------+--------------------+---------------+--------------+----------+------------+----------------+--------+----------+------------+-------+------------+------------+----------+-------------------+------------+----------+--------------+
# only showing top 20 rows

# %%
df1 = df1.withColumn("customer_name", regexp_extract(col("customer_name"),r"([a-zA-Z]+)",1))

# %%
value = df1.groupBy("product_category").agg(count("*").alias("count")).orderBy(col("count").desc()).limit(2).orderBy(col("count").asc()).limit(1).collect()[0][0]

# %%
df1 = df1.withColumn("product_category", when(col("product_category") == 'INVALID',value).otherwise(col("product_category")))

# %%
df1 = df1.withColumn("quantity",when(col("quantity") < 0 , col("quantity")*col("quantity")).otherwise(col("quantity")))

# %%
df1.withColumn("Year",year(col("order_date")))\
.withColumn("month",month(col("order_date")))\
.withColumn("day",day(col("order_date"))).show()
# Out:
# +--------------+--------+-----------+-------------+--------------------+---------------+--------------+----------+------------+----------------+--------+----------+------------+-------+------------+------------+----------+-------------------+------------+----------+--------------+----+-----+---+
# |transaction_id|order_id|customer_id|customer_name|      customer_email|  customer_city|customer_state|product_id|product_name|product_category|quantity|unit_price|discount_pct|tax_pct|payment_mode|order_status|order_date|ingestion_timestamp|gross_amount|net_amount|rejection_flag|Year|month|day|
# +--------------+--------+-----------+-------------+--------------------+---------------+--------------+----------+------------+----------------+--------+----------+------------+-------+------------+------------+----------+-------------------+------------+----------+--------------+----+-----+---+
# |             1| ORD1001|       C005|      Patrick|vcunningham@sanch...|       Grayview|            MH|      P231|      result|     Electronics|       3|         0|           0|     18|        CASH|   DELIVERED|2026-01-02|            35:43.9|        NULL|      NULL|          true|2026|    1|  2|
# |             2| ORD1002|       C018|       Hector|stephaniewatson@m...|     South Lisa|            KA|      P178|        call|       Furniture|       1|       100|          10|     18|        CASH|   DELIVERED|2025-12-28|            16:43.9|        NULL|      NULL|          true|2025|   12| 28|
# |             3| ORD1003|       C022|       Andrew| bschaefer@yahoo.com|      Lake Lisa|            MH|      P233|      manage|     Electronics|       2|         0|          10|     18|         UPI|   CANCELLED|2026-01-02|            44:43.9|        NULL|      NULL|          true|2026|    1|  2|
# |             4| ORD1004|       C032|     Brittany|bernardnovak@herr...|   Evansborough|            XX|      P201|      rather|     Electronics|       3|         0|          10|      5|         UPI|    RETURNED|2025-12-28|            28:43.9|        NULL|      NULL|          true|2025|   12| 28|
# |             5| ORD1005|       C029|       Monica|    yharris@huff.com|South Alexander|            KA|      P202|       staff|     Electronics|       1|       100|           5|     12|        CASH|    RETURNED|2026-01-02|            55:43.9|        NULL|      NULL|          true|2026|    1|  2|
# |             6| ORD1006|       C050|        Aaron| graynancy@yahoo.com|    Kathleenton|            MH|      P112|          in|     Electronics|       2|         0|          15|     12|        CARD|    RETURNED|2026-01-02|            21:43.9|        NULL|      NULL|          true|2026|    1|  2|
# |             7| ORD1007|       C046|       Joshua|hardyernest@gmail...|     South Mary|            MH|      P231|      camera|     Electronics|       2|       500|          15|      5|         UPI|    RETURNED|2026-01-02|            03:43.9|        1000|       850|          true|2026|    1|  2|
# |             8| ORD1008|       C029|       Steven|randymosley@hotma...|South Meganberg|            MH|      P140|       about|     Electronics|       1|         0|           0|     18|        CASH|    RETURNED|2026-01-02|            37:43.9|        NULL|      NULL|          true|2026|    1|  2|
# |             9| ORD1009|       C042|         Jill| wendy06@hotmail.com|     Lake Dylan|            KA|      P273|    continue|     Electronics|       3|       500|          15|     12|        CARD|   DELIVERED|2025-12-28|            07:43.9|        1500|      1275|         false|2025|   12| 28|
# |            10| ORD1010|       C027|       Daniel| debrahall@yahoo.com|  New Bryantown|            KA|      P184|       voice|       Furniture|       1|         0|           0|     12|        CARD|   CANCELLED|2025-12-28|            12:43.9|        NULL|      NULL|          true|2025|   12| 28|
# |            11| ORD1011|       C010|        Terri|     xcook@gmail.com|      Ericmouth|            KA|      P202|         red|     Electronics|       2|       100|           5|      5|        CASH|   DELIVERED|2026-01-02|            49:43.9|         200|       190|          true|2026|    1|  2|
# |            12| ORD1012|       C005|         John|    ogomez@yahoo.com|     Jonesmouth|            MH|      P195|         hot|     Electronics|       1|       500|           5|      5|         UPI|   DELIVERED|2026-01-02|            30:43.9|        NULL|      NULL|          true|2026|    1|  2|
# |            13| ORD1013|       C027|       Justin|lindsey23@singh-n...|      Welchbury|            XX|      P114|     compare|     Electronics|       1|       500|           5|      5|        CASH|   DELIVERED|2025-12-28|            05:43.9|         500|       475|         false|2025|   12| 28|
# |            14| ORD1014|       C010|         Levi|zdouglas@wiley-st...|    New Matthew|            KA|      P228|       claim|     Electronics|       2|       100|           5|      5|         UPI|    RETURNED|2025-12-28|            07:43.9|         200|       190|         false|2025|   12| 28|
# |          NULL| ORD1015|       C042|     Victoria|   kim36@hotmail.com|  South Cynthia|            MH|      P110|     reflect|       Furniture|       3|         0|           0|      5|        CASH|   DELIVERED|2026-01-02|            25:43.9|        NULL|      NULL|          true|2026|    1|  2|
# |            16| ORD1016|       C043|        Kevin|grayhannah@hotmai...|  New Joelmouth|            KA|      P242|        wide|     Electronics|       1|         0|           0|     18|        CASH|   DELIVERED|2025-12-28|            22:43.9|        NULL|      NULL|          true|2025|   12| 28|
# |            17| ORD1017|       C034|        Randy|nicholasgonzales@...|  Kimberlymouth|            KA|      P250|       glass|       Furniture|       3|       100|           0|     18|         UPI|    RETURNED|2025-12-28|            13:43.9|         300|       300|         false|2025|   12| 28|
# |            18| ORD1018|       C002|        Kevin|           bad_email|   South Andrea|            KA|      P125|        dark|     Electronics|       1|       100|          15|     12|        CARD|    RETURNED|2025-12-28|            22:43.9|         100|        85|         false|2025|   12| 28|
# |            19| ORD1019|       C022|        Jason|orodriguez@fields...|    Port Pamela|            XX|      P170|         not|     Electronics|       1|         0|          10|     12|        CARD|   CANCELLED|2025-12-28|            17:43.9|        NULL|      NULL|          true|2025|   12| 28|
# |            20| ORD1005|       C021|     Patricia|jasondiaz@wallace...|        Hahnton|            MH|      P242|   financial|     Electronics|       3|       100|           5|     12|        CARD|   DELIVERED|2025-12-28|            27:43.9|         300|       285|         false|2025|   12| 28|
# +--------------+--------+-----------+-------------+--------------------+---------------+--------------+----------+------------+----------------+--------+----------+------------+-------+------------+------------+----------+-------------------+------------+----------+--------------+----+-----+---+
# only showing top 20 rows
